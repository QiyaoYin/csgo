# %%
import requests
from hyper.contrib import HTTP20Adapter
import time
from threading import Thread
import json

# %%
def current_milli_time():
    return str(round(time.time() * 1000))
domain = 'https://buff.163.com'
cookie = 'Device-Id=xsTUySJ9cGu53kLrQSZ1; game=csgo; Locale-Supported=zh-Hans; NTES_YD_SESS=Ir9ONgNWw_qHC1hq7CkH0Ccd60LDIVnCfU50aRqGaEnwYtclYUOmhkjnfydaIH4sQI6_lXnrSAhDl_J7FBc55V0kvTzg8VmzkrAPJRveyB6qkD8Wkiv8qEjTYjE1YdUX_HrRHpfhXwMI5dmfy12ZgMZNf0I1A6BbXQJ05PlFpAddYCibW97UWnCBWzRB2R9BNViacSTi8yNz29Jo8DoKxzdwKRaeELsN.FcGx52e._HpD; S_INFO=1681047179|0|0&60##|19154957874; P_INFO=19154957874|1681047179|1|netease_buff|00&99|null&null&null#zhj&330200#10#0|&0|null|19154957874; remember_me=U1106755806|WaqmJUZwAeXwS7cW3hgxJIxThoW6VLBB; session=1-d0KMl1E6emF95YIXclW0w3oRjDls5z48eHZtprtaiYgD2033803142; '   
csrf_token = 'csrf_token=ImU1YTg5MmYzNTU4MGE4YTBjZWViYzJkOWQwMDI0MTFkMGI2ZjZlOWEi.FxRRag.BHjhFc5LELbMSDowiYsW-ajaaIE'
headers = {
    ':authority': 'buff.163.com',
    ':scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6',
    'sec-ch-ua': '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mod': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest'
}
goods_id = '900464'# 反冲
pay_method = '3' # weixing: 6. BUFF余额-支付宝: 3. 
message = 'add a new container jerryin jerry'
sessions = requests.session()
sessions.mount(domain, HTTP20Adapter())
sessions.headers = headers

buy_cookie = 'Device-Id=xsTUySJ9cGu53kLrQSZ1; game=csgo; Locale-Supported=zh-Hans; NTES_YD_SESS=1sKwdhWrXqWwLqLHaaxOXc7KB7GXOu3uaMhtZsrmZzi_7LHE7Muc9bHfwL5L2VqCR2VaG8sos9soNg9B.B3MEViw7LjJ14hr8BbLG.4nBSm411Bo4._wSbYV7YzW7jMpkCXsC.n9p_R1hjcnNWPTIRTBnt1WGf5KpyathQEJ.GjZxjfF51DiwgwC_J6VUQZ9IQQSf4ZuYywJ3rCixj5gczzj_XRW3edZelda5RRejQ5_x; S_INFO=1681048663|0|0&60##|17376591844; P_INFO=17376591844|1681048663|1|netease_buff|00&99|null&null&null#zhj&330200#10#0|&0|null|17376591844; remember_me=U1106621510|ZRhqhsJSWApe3Wnhg3wNrf4mQ1FRuJgV; session=1-T85gyJnmZK7k79MeX0XEqZvJPJO-7WH1byp8L7kVMoU-2033920798; '
buy_csrf_token = 'csrf_token=IjcxMWZiNzhhNWYxM2I2NDhiZmNiMDllZjI4MjViYWFhMzBiZTc1NDki.FxRWDg.YeaR1frIjakmjMw3UlQa9heFC7Y'
buy_session = requests.session()
buy_session.mount(domain, HTTP20Adapter())
buy_session.headers = headers

# %%
def notification(session, domain, cookie, csrf_token):
    _path = '/api/message/notification?_=' + current_milli_time()
    _url = domain + _path
    _header = {
        ':method': 'GET',
        ':path': _path,
        'cookie': cookie + csrf_token,
        'referer': domain + '/?game=csgo'
    }
    return session.get(_url, headers = _header)

# %%
csrf_token = notification(sessions, domain, cookie, csrf_token).headers.get(b'set-cookie').decode("utf-8").split(';')[0]

# %%
def get_goods_data(session, domain, cookie, csrf_token, goods_id):
    # 裂空武器箱:781534
    _path = '/api/market/goods/sell_order?game=csgo&goods_id=' + goods_id + '&page_num=1&sort_by=price.asc&mode=&allow_tradable_cooldown=1&_=' + current_milli_time()
    _url = domain + _path
    _header = {
        ':method': 'GET',
        ':path': _path,
        'cookie': cookie + csrf_token,
        'referer': domain + '/goods/' + goods_id,
    }
    return session.get(_url, headers = _header)

# %%
# def preview(session, domain, cookie, csrf_token, game, goods_id, sell_order_id, price):
#     _path = '/api/market/goods/buy/preview?game=csgo&sell_order_id=' + sell_order_id + '&goods_id=' + goods_id + '&price=' + price + '&allow_tradable_cooldown=0&cdkey_id=&_=' + current_milli_time()
#     _url = domain + _path
#     _header = {
#         ':method': 'GET',
#         ':path': _path,
#         'cookie': cookie + csrf_token,
#         'referer': domain + '/goods/' + goods_id + '?from=market',
#     }
#     return session.get(_url, headers = _header)

# %%
# csrf_token = preview(sessions, domain, cookie, csrf_token, 'csgo', goods_id, item['id'], item['price']).headers.get(b'set-cookie').decode("utf-8").split(';')[0]

# %%
def buy_goods(session, domain, cookie, csrf_token, game, goods_id, sell_order_id, price, pay_method, allow_tradable_cooldown, token, cdkey_id):
    _path = '/api/market/goods/buy'
    _url = domain + _path
    _header = {
        ':method': 'POST',
        ':path': _path,
        'referer': domain + '/goods/' + goods_id,
        'content-type': 'application/json',
        'origin': domain,
        'cookie': cookie + csrf_token,
        'x-csrftoken': csrf_token.split('=')[1]
    }

    form_data = {
        "game": game,
        "goods_id":goods_id,
        "sell_order_id": sell_order_id,
        "price": price,
        "pay_method": pay_method,
        "allow_tradable_cooldown": allow_tradable_cooldown,
        "token": token,
        "cdkey_id":cdkey_id
    }
    r = session.post(_url, headers = _header, json = form_data)
    return r.json()

# %%
def sendMessage(message):
    _url = "https://oapi.dingtalk.com/robot/send?access_token=35a63d6aae0234ee0e794b7f6cec9ec06a44cd89f42c6d9d336488730494f50c"
    headers = {'Content-Type':'application/json'}
    data = {"msgtype":"text","text":{ "content": message}}
    requests.post(_url, data = json.dumps(data), headers = headers)

# %%
# print(buy_goods(sessions, domain, cookie, csrf_token, 'csgo', goods_id, item['id'], item['price'], pay_method, '0', '', ''))
for i in range(0, 10):
    t = 1
    buy_csrf_token = notification(buy_session, domain, buy_cookie, buy_csrf_token).headers.get(b'set-cookie').decode("utf-8").split(';')[0]
    while(1):
        time.sleep(t)
        try:
            resp = get_goods_data(sessions, domain, cookie, csrf_token, goods_id)
            item = resp.json()['data']['items'][0]
            csrf_token = resp.headers.get(b'set-cookie').decode("utf-8").split(';')[0]
            if(float(item['price']) < 7):
                buy_goods(buy_session, domain, buy_cookie, buy_csrf_token, 'csgo', goods_id, item['id'], item['price'], pay_method, '0', '', '')
                print(item['price'])
                sendMessage(message + item['price'])
                break
            if t > 1:
                t -= 0.5
        except Exception as e:
            t += 1
            print(e)
            continue
# Out:
# 'data'
# 'data'
# 'data'
# Stream forcefully closed
# 6.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-acb966e65485> in <module>
#       4     buy_csrf_token = notification(buy_session, domain, buy_cookie, buy_csrf_token).headers.get(b'set-cookie').decode("utf-8").split(';')[0]
#       5     while(1):
# ----> 6         time.sleep(t)
#       7         try:
#       8             resp = get_goods_data(sessions, domain, cookie, csrf_token, goods_id)
#
# KeyboardInterrupt:

# %%
class test(object):
    def __init__(self, i):
        self.i = i

# %%
t0 = test(0)
t1 = test(1)
t2 = test(2)
a = [t0, t1, t2]
b = a[2]
print(len(a))
a.remove(b)
b.i
# Out:
# 3
# 2

# %%
len(a)
# Out:
# 2

# %%
def getIpToken():
    form_data = {
        'secret_id': 'o81ooetpm0jqbtoauegq',
        'secret_key': 'rc4cbfb9wslxolylje30wgj0q8yqzngz'
    }
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
    }
    return requests.post('https://auth.kdlapi.com/api/get_secret_token', headers = headers, json = form_data).json()

# %%
a = ['1', '2', '3', '20230420T12313']

# %%
'20230420T12313' in a
# Out:
# True

# %%
{
  "code": "OK", 
  "data": {
    "fop_str": "?fop=imageView/2/w/245/h/230", 
    "goods_infos": {
      "45237": {
        "appid": 730, 
        "can_3d_inspect": false, 
        "can_inspect": false, 
        "description": null, 
        "game": "csgo", 
        "goods_id": 45237, 
        "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "item_id": null, 
        "market_hash_name": "Clutch Case", 
        "market_min_price": "0", 
        "name": "Clutch Case", 
        "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
        "short_name": "Clutch Case", 
        "steam_price": "1.42", 
        "steam_price_cny": "9.78", 
        "tags": {
          "category": {
            "category": "category", 
            "id": 664, 
            "internal_name": "csgo_type_weaponcase", 
            "localized_name": "Weapon Cases"
          }, 
          "category_group": {
            "category": "category_group", 
            "id": 657, 
            "internal_name": "other", 
            "localized_name": "Others"
          }, 
          "custom": {
            "category": "custom", 
            "id": 8468, 
            "internal_name": "Clutch", 
            "localized_name": "clutch"
          }, 
          "itemset": {
            "category": "itemset", 
            "id": 3935, 
            "internal_name": "set_community_19", 
            "localized_name": "set_community_19"
          }, 
          "quality": {
            "category": "quality", 
            "id": 516, 
            "internal_name": "normal", 
            "localized_name": "Normal"
          }, 
          "rarity": {
            "category": "rarity", 
            "id": 594, 
            "internal_name": "common", 
            "localized_name": "Base Grade"
          }, 
          "type": {
            "category": "type", 
            "id": 572, 
            "internal_name": "csgo_type_weaponcase", 
            "localized_name": "Weapon Cases"
          }, 
          "weaponcase": {
            "category": "weaponcase", 
            "id": 11526, 
            "internal_name": "Clutch Case", 
            "localized_name": "clutch case"
          }
        }
      }
    }, 
    "has_market_stores": {
      "U1094351240": true, 
      "U1097279506": true, 
      "U1097434088": true
    }, 
    "items": [
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "26587137462", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003103, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199043", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003103, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "26145835028", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003104, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199102", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003104, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "25634952874", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003104, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199072", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003104, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "25558462831", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003105, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321198995", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003105, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "24903555201", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003105, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321198991", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003105, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "24849148039", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003106, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199034", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003106, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "20764551744", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003106, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199019", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "7.5", 
        "mode": 5, 
        "price": "7.5", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003106, 
        "user_id": "U1097434088"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "28149041828", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003103, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199060", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "8", 
        "mode": 5, 
        "price": "8", 
        "recent_average_duration": 129.0, 
        "recent_deliver_rate": 1.0, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003103, 
        "user_id": "U1094351240"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "28149875072", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003106, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199025", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "8", 
        "mode": 5, 
        "price": "8", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003106, 
        "user_id": "U1097279506"
      }, 
      {
        "allow_bargain": true, 
        "appid": 730, 
        "asset_info": {
          "action_link": "", 
          "appid": 730, 
          "assetid": "27916388079", 
          "classid": "2727227113", 
          "contextid": 2, 
          "goods_id": 45237, 
          "has_tradable_cooldown": false, 
          "info": {
            "fraudwarnings": null, 
            "icon_url": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
            "original_icon_url": "https://g.fp.ps.netease.com/market/file/5a86571669b21a59fa4a46d09Va36sui", 
            "stickers": [], 
            "tournament_tags": []
          }, 
          "instanceid": "0", 
          "paintwear": "", 
          "tradable_cooldown_text": "", 
          "tradable_unfrozen_time": null
        }, 
        "background_image_url": "https://buff.163.com/static/images/item_bg.png", 
        "bookmarked": false, 
        "can_bargain": true, 
        "can_use_inspect_trn_url": false, 
        "cannot_bargain_reason": "", 
        "created_at": 1682003106, 
        "description": "", 
        "featured": 0, 
        "fee": "0", 
        "game": "csgo", 
        "goods_id": 45237, 
        "id": "230420T0321199018", 
        "img_src": "https://g.fp.ps.netease.com/market/file/5a9fe246fb758acf3db7dc6fzK9qCbh3", 
        "income": "0", 
        "lowest_bargain_price": "8", 
        "mode": 5, 
        "price": "8", 
        "recent_average_duration": null, 
        "recent_deliver_rate": null, 
        "state": 1, 
        "supported_pay_methods": [
          3, 
          1, 
          6, 
          7, 
          10, 
          11
        ], 
        "tradable_cooldown": null, 
        "updated_at": 1682003106, 
        "user_id": "U1097279506"
      }
    ], 
    "page_num": 1, 
    "page_size": 10, 
    "preview_screenshots": {
      "bg_img": "https://spect.fp.ps.netease.com/file/613abf6309463c49b9c8aa93Mt9e2tVQ03", 
      "selling": "on"
    }, 
    "show_game_cms_icon": false, 
    "show_pay_method_icon": true, 
    "sort_by": "price.asc", 
    "src_url_background": "https://buff.163.com/static/images/item_bg.png", 
    "total_count": 91, 
    "total_page": 10, 
    "user_infos": {
      "U1094351240": {
        "avatar": "https://g.fp.ps.netease.com/market/file/5dc7d2a396dee459c0111e0dbTlZbRrO02", 
        "avatar_safe": "https://g.fp.ps.netease.com/market/file/5dc7d2a396dee459c0111e0dbTlZbRrO02", 
        "is_auto_accept": false, 
        "is_premium_vip": false, 
        "nickname": "\u5176\u540d\u4e3a\u4e00", 
        "seller_level": 0, 
        "shop_id": "1094351240", 
        "user_id": "U1094351240", 
        "v_types": null
      }, 
      "U1097279506": {
        "avatar": "https://g.fp.ps.netease.com/market/file/609412c86f0494620d6fc283jQiYPjHO03", 
        "avatar_safe": "https://g.fp.ps.netease.com/market/file/609412c86f0494620d6fc283jQiYPjHO03", 
        "is_auto_accept": false, 
        "is_premium_vip": false, 
        "nickname": "\u5e0c\u5e0c\u7b11", 
        "seller_level": 0, 
        "shop_id": "1097279506", 
        "user_id": "U1097279506", 
        "v_types": null
      }, 
      "U1097434088": {
        "avatar": "https://g.fp.ps.netease.com/market/file/5c4994af8b7427196aca7aeblbTq8TJS02", 
        "avatar_safe": "https://g.fp.ps.netease.com/market/file/5c4994af8b7427196aca7aeblbTq8TJS02", 
        "is_auto_accept": false, 
        "is_premium_vip": false, 
        "nickname": "\u4f4e\u4ef7\u51fa\u5feb\u70b9", 
        "seller_level": 0, 
        "shop_id": "1097434088", 
        "user_id": "U1097434088", 
        "v_types": null
      }
    }
  }, 
  "msg": null
}
